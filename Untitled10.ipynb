# %%
# !pip install yfinance pandas numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: yfinance in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (0.2.55)
# Requirement already satisfied: pandas in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (2.2.4)
# Requirement already satisfied: matplotlib in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (3.10.1)
# Requirement already satisfied: scikit-learn in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Requirement already satisfied: requests>=2.31 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\okechpc\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

# %%
# Define the ETF symbol (e.g., XLRE)
etf_symbol = 'XLRE'

# Fetch 6 months of daily data (~120 data points)
data = yf.download(etf_symbol, period="6mo", interval="1d")

# Display the first few rows of data
data.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker           XLRE       XLRE       XLRE       XLRE     XLRE
# Date
# 2024-10-14  42.989559  43.048545  42.478363  42.586501  3542900
# 2024-10-15  43.530243  43.884148  43.146847  43.176338  5176300
# 2024-10-16  43.962795  44.026693  43.500752  43.628552  3662700
# 2024-10-17  43.677708  43.874322  43.510584  43.834998  2934000
# 2024-10-18  43.982456  43.998184  43.594144  43.766180  3950800

# %%
# Check the column names in the dataset
print(data.columns)
# Out:
# MultiIndex([( 'Close', 'XLRE'),
#             (  'High', 'XLRE'),
#             (   'Low', 'XLRE'),
#             (  'Open', 'XLRE'),
#             ('Volume', 'XLRE')],
#            names=['Price', 'Ticker'])

# %%
# Access the 'Close' prices for 'XLRE'
data['Daily_Returns'] = data[('Close', 'XLRE')].pct_change()

# Drop the missing values that appear due to pct_change calculation
data.dropna(inplace=True)

# Display the first few rows of the 'Close' price and 'Daily_Returns' for XLRE
print(data[[( 'Close', 'XLRE')]].head())  # Display 'Close' data for XLRE
print(data[['Daily_Returns']].head())  # Display 'Daily_Returns'
# Out:
# Price           Close
# Ticker           XLRE
# Date
# 2024-10-16  43.962795
# 2024-10-17  43.677708
# 2024-10-18  43.982456
# 2024-10-21  43.078033
# 2024-10-22  43.146847
# Price      Daily_Returns
# Ticker
# Date
# 2024-10-16      0.009937
# 2024-10-17     -0.006485
# 2024-10-18      0.006977
# 2024-10-21     -0.020563
# 2024-10-22      0.001597

# %%
# Drop missing values created by the pct_change calculation
data.dropna(inplace=True)

# %%
# Display the first few rows of the 'Close' price and 'Daily_Returns'
print(data[[( 'Close', 'XLRE')]].head())  # Display 'Close' data for XLRE
print(data[['Daily_Returns']].head())  # Display 'Daily_Returns'
# Out:
# Price           Close
# Ticker           XLRE
# Date
# 2024-10-16  43.962795
# 2024-10-17  43.677708
# 2024-10-18  43.982456
# 2024-10-21  43.078033
# 2024-10-22  43.146847
# Price      Daily_Returns
# Ticker
# Date
# 2024-10-16      0.009937
# 2024-10-17     -0.006485
# 2024-10-18      0.006977
# 2024-10-21     -0.020563
# 2024-10-22      0.001597

# %%
# Display the last few rows of the 'Close' price and 'Daily_Returns'
print(data[[( 'Close', 'XLRE')]].tail())  # Display 'Close' data for XLRE
print(data[['Daily_Returns']].tail())  # Display 'Daily_Returns'
# Out:
# Price           Close
# Ticker           XLRE
# Date
# 2025-04-08  37.080002
# 2025-04-09  39.209999
# 2025-04-10  38.380001
# 2025-04-11  38.919998
# 2025-04-14  39.689999
# Price      Daily_Returns
# Ticker
# Date
# 2025-04-08     -0.024724
# 2025-04-09      0.057443
# 2025-04-10     -0.021168
# 2025-04-11      0.014070
# 2025-04-14      0.019784

# %%
# Compute the variance for the daily returns (since it's a single time series)
variance = data['Daily_Returns'].var()

# Print the variance
print(f"Variance of Daily Returns: {variance}")
# Out:
# Variance of Daily Returns: 0.00018052661911930313

# %%
#Perform Principal Component Analysis (PCA)
#Reshape the data to apply PCA
returns_data = data[['Daily_Returns']].values.reshape(-1, 1)

# %%
#Perform PCA
pca = PCA(n_components=1)  # One component since we're dealing with a single time series here
pca.fit(returns_data)
# Out:
# PCA(n_components=1)

# %%
#Get explained variance ratio and components
explained_variance = pca.explained_variance_ratio_
components = pca.components_

# %%
# Print PCA results
print(f'Explained Variance: {explained_variance}')
print(f'PCA Components: {components}')
# Out:
# Explained Variance: [1.]
# PCA Components: [[1.]]

# %%
#Perform Singular Value Decomposition (SVD)
#Create a second feature: Lagged returns (previous day's returns)
data['Lagged_Returns'] = data['Daily_Returns'].shift(1)

#Drop any missing values created by the lagging
data.dropna(inplace=True)

#'Daily_Returns' and 'Lagged_Returns'
returns_data_svd = data[['Daily_Returns', 'Lagged_Returns']].values

#Apply SVD
svd = TruncatedSVD(n_components=1)
svd.fit(returns_data_svd)

#Get the singular values and components
singular_values = svd.singular_values_
components_svd = svd.components_

# Print SVD results
print(f'Singular Values: {singular_values}')
print(f'SVD Components: {components_svd}')
# Out:
# Singular Values: [0.15333196]
# SVD Components: [[ 0.73729909 -0.67556647]]

# %%
#Visualize the daily returns
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Daily_Returns'], label='Daily Returns', color='b')
plt.title('Daily Returns of XLRE ETF')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.grid(True)
plt.show()
